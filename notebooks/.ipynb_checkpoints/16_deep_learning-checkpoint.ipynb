# %%
from sklearn import datasets, metrics
import tensorflow as tf
import numpy as np
from sklearn.cross_validation import train_test_split
# %matplotlib inline
# Out:
# /Users/sinanozdemir/anaconda/envs/sfdat26-env/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# Data set of IRIS
iris = datasets.load_iris()

# Load datasets and split them for training and testing
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target)


####### TENSORFLOW #####

# Here is tensorflow's syntac for defining features.
# We must specify that all features have real-value data
feature_columns = [tf.contrib.layers.real_valued_column("", dimension=4)]

optimizer = tf.train.GradientDescentOptimizer(learning_rate=.1)


# Build a linear classifier (logistic regression)
# note we have to tell tensorfow the number of classes we are looking for
classifier = tf.contrib.learn.LinearClassifier(feature_columns=feature_columns,
                                               optimizer=optimizer,
                                            n_classes=3)

# Fit model. Uses error optimization techniques like stochastic gradient descent
classifier.fit(x=X_train,
               y=y_train,
               steps=1000)  # number of iterations

# Evaluate accuracy.
accuracy_score = classifier.evaluate(x=X_test,
                                     y=y_test)["accuracy"]
print('Accuracy: {0:f}'.format(accuracy_score))

# Classify two new flower samples.
new_samples = np.array(
    [[6.4, 3.2, 4.5, 1.5], [5.8, 3.1, 5.0, 1.7]], dtype=float)
y = classifier.predict(new_samples)
print('Predictions: {}'.format(str(y)))
# Out:
# WARNING:tensorflow:Change warning: default value of `enable_centered_bias` will change after 2016-10-09. It will be disabled by default.Instructions for keeping existing behaviour:
# Explicitly set `enable_centered_bias` to 'True' if you want to keep existing behaviour.
# WARNING:tensorflow:Using default config.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:tf.variable_op_scope(values, name, default_name) is deprecated, use tf.variable_scope(name, default_name, values)
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# WARNING:tensorflow:tf.variable_op_scope(values, name, default_name) is deprecated, use tf.variable_scope(name, default_name, values)
# WARNING:tensorflow:Calling predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:tf.variable_op_scope(values, name, default_name) is deprecated, use tf.variable_scope(name, default_name, values)
# Accuracy: 0.973684
# Predictions: [1 2]

# %%
classifier.__dict__
# Out:
# {'_estimator': Estimator(params={'enable_centered_bias': True, 'weight_column_name': None, 'optimizer': <tensorflow.python.training.gradient_descent.GradientDescentOptimizer object at 0x10bfa0e90>, 'feature_columns': [_RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)], 'n_classes': 3, 'joint_weights': False, 'gradient_clip_norm': None, 'num_ps_replicas': 0}),
#  '_feature_columns': [_RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)],
#  '_model_dir': '/var/folders/5m/23l3y1w92r9fyzp935vxsfkm0000gn/T/tmp8ZuB8H',
#  '_n_classes': 3,
#  '_optimizer': <tensorflow.python.training.gradient_descent.GradientDescentOptimizer at 0x10bfa0e90>,
#  '_weight_column_name': None}

# %%
# Make a Deep Neural Network (DNN)

# %%
# Data sets
iris = datasets.load_iris()

# Load datasets.
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target)

# Specify that all features have real-value data
feature_columns = [tf.contrib.layers.real_valued_column("", dimension=4)]

optimizer = tf.train.GradientDescentOptimizer(learning_rate=.1)


# Build 3 layer DNN with 10, 20, 10 units respectively.
classifier = tf.contrib.learn.DNNClassifier(feature_columns=feature_columns,
                                            hidden_units=[10, 20, 10],
                                            optimizer=optimizer,
                                            n_classes=3)

# Fit model.
classifier.fit(x=X_train,
               y=y_train,
               steps=2000)

# Evaluate accuracy.
accuracy_score = classifier.evaluate(x=X_test,
                                     y=y_test)["accuracy"]
print('Accuracy: {0:f}'.format(accuracy_score))

# Classify two new flower samples.
new_samples = np.array(
    [[6.4, 3.2, 4.5, 1.5], [5.8, 3.1, 5.0, 1.7]], dtype=float)
y = classifier.predict(new_samples)
print('Predictions: {}'.format(str(y)))
# Out:
# WARNING:tensorflow:Change warning: default value of `enable_centered_bias` will change after 2016-10-09. It will be disabled by default.Instructions for keeping existing behaviour:
# Explicitly set `enable_centered_bias` to 'True' if you want to keep existing behaviour.
# WARNING:tensorflow:Using default config.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# WARNING:tensorflow:Calling predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# WARNING:tensorflow:Calling predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# Accuracy: 0.973684
# Predictions: [1 2]

# %%
classifier.__dict__
# Out:
# {'_estimator': Estimator(params={'enable_centered_bias': True, 'weight_column_name': None, 'optimizer': <tensorflow.python.training.gradient_descent.GradientDescentOptimizer object at 0x13d264750>, 'feature_columns': [_RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)], 'n_classes': 3, 'joint_weights': False, 'gradient_clip_norm': None, 'num_ps_replicas': 0}),
#  '_feature_columns': [_RealValuedColumn(column_name='', dimension=4, default_value=None, dtype=tf.float32, normalizer=None)],
#  '_model_dir': '/var/folders/5m/23l3y1w92r9fyzp935vxsfkm0000gn/T/tmpgSphOy',
#  '_n_classes': 3,
#  '_optimizer': <tensorflow.python.training.gradient_descent.GradientDescentOptimizer at 0x13d264750>,
#  '_weight_column_name': None}

# %%
# Data sets
iris = datasets.load_iris()

# Load datasets.
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target)

# Specify that all features have real-value data
feature_columns = [tf.contrib.layers.real_valued_column("", dimension=4)]

optimizer = tf.train.GradientDescentOptimizer(learning_rate=.1)


# Build 3 layer DNN with 10, 20, 10 units respectively.
classifier = tf.contrib.learn.DNNClassifier(feature_columns=feature_columns,
                                            hidden_units=[10, 20, 20, 10],
                                            optimizer=optimizer,
                                            n_classes=3)

# Fit model.
classifier.fit(x=X_train,
               y=y_train,
               steps=2000)

# Evaluate accuracy.
accuracy_score = classifier.evaluate(x=X_test,
                                     y=y_test)["accuracy"]
print('Accuracy: {0:f}'.format(accuracy_score))

# Classify two new flower samples.
new_samples = np.array(
    [[6.4, 3.2, 4.5, 1.5], [5.8, 3.1, 5.0, 1.7]], dtype=float)
y = classifier.predict(new_samples)
print('Predictions: {}'.format(str(y)))
# Out:
# WARNING:tensorflow:Change warning: default value of `enable_centered_bias` will change after 2016-10-09. It will be disabled by default.Instructions for keeping existing behaviour:
# Explicitly set `enable_centered_bias` to 'True' if you want to keep existing behaviour.
# WARNING:tensorflow:Using default config.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# WARNING:tensorflow:Calling predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# WARNING:tensorflow:Calling predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# Accuracy: 1.000000
# Predictions: [1 2]

# %%
# HOT DAMN SLOW DOWN TENSORFLOW

# %%
# Object Detection

# %%
from glob import glob
from pylab import imread, imsave, subplot, imshow, title, gray, figure, show, NullLocator
from numpy import mean, cov, dot, linalg, size, argsort
import PIL
from PIL import Image

# %%
# read in the images

image_dict = {'image':[], 'target': []}
code_to_target = {}
i = 0
size = 128, 128
for folder in glob('../data/objects/*'):
    name_of_object= folder.split('/')[-1]
    if name_of_object not in ['Motorbikes', 'octopus', 'accordion', 'stop_sign']:
        continue
    code_to_target[i] = name_of_object
    print name_of_object
    for f in glob(folder+'/*')[:20]:  # only take the first 50 images
        try:
            img = Image.open(f)
            img = img.resize(size, Image.ANTIALIAS) # resize image to 128 by 128 for ease
            img.save(f, "JPEG") # resave the image back to the folder
            row = imread(f) # load an image  # load it into numpy
            row = row.reshape(49152)  # turn it into a 1d array
            image_dict['image'].append(row)
            image_dict['target'].append(i)
        except Exception as e:
            pass
        
    i += 1
# Out:
# accordion
# Motorbikes
# octopus
# stop_sign

# %%
image_dict['image'][0].shape
# Out:
# (49152,)

# %%
images_X = np.array(image_dict['image']).astype(float)
images_y = np.array(image_dict['target'])

# %%
# Load datasets.
X_train, X_test, y_train, y_test = train_test_split(images_X, images_y)

# %%
## WARNING SLOWWWWW ##

# Specify that all features have real-value data
feature_columns = [tf.contrib.layers.real_valued_column("", dimension=49152)]

optimizer = tf.train.GradientDescentOptimizer(learning_rate=.01)


# Build DNN
classifier = tf.contrib.learn.DNNClassifier(feature_columns=feature_columns,
                                            hidden_units=[100,100,100,100],
                                            optimizer=optimizer,
                                            n_classes=len(code_to_target))

# Fit model.
classifier.fit(x=X_train,
               y=y_train,
               steps=10000)
# Out:
# WARNING:tensorflow:Change warning: default value of `enable_centered_bias` will change after 2016-10-09. It will be disabled by default.Instructions for keeping existing behaviour:
# Explicitly set `enable_centered_bias` to 'True' if you want to keep existing behaviour.
# WARNING:tensorflow:Using default config.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# Estimator(params={'enable_centered_bias': True, 'activation_fn': <function relu at 0x11176f668>, 'weight_column_name': None, 'hidden_units': [100, 100, 100, 100], 'feature_columns': [_RealValuedColumn(column_name='', dimension=49152, default_value=None, dtype=tf.float32, normalizer=None)], 'n_classes': 4, 'optimizer': <tensorflow.python.training.gradient_descent.GradientDescentOptimizer object at 0x121ab2c50>, 'dropout': None, 'gradient_clip_norm': None, 'num_ps_replicas': 0})

# %%
# Evaluate accuracy.
accuracy_score = classifier.evaluate(x=X_test,
                                     y=y_test)["accuracy"]
print('Accuracy: {0:f}'.format(accuracy_score))
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 49152), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(49152)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# Accuracy: 0.980000

# %%
# Ideally we would train more and larger hidden layers, but the idea will come across

# %%
# I found this gem of an image on Google Images

# %%
url = '../data/accordion_band.jpg'
image = imread(url) # load an image
image.shape
# Out:
# (707, 1280, 3)

# %%
imshow(image)  # such class

# %%
import random
random_x_coordinate = random.choice(range(1,image.shape[0]-128))
random_y_coordinate = random.choice(range(1,image.shape[0]-128))  # choose a random starting point
subset = image[random_y_coordinate:random_y_coordinate+128,random_x_coordinate:random_x_coordinate+128,]
imshow(subset)
print classifier.predict_proba(subset.reshape(49152))[0]
code_to_target[classifier.predict(subset.reshape(49152))[0]]
# Out:
# WARNING:tensorflow:Calling predict_proba (from tensorflow.contrib.learn.python.learn.estimators.dnn) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# WARNING:tensorflow:Calling predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# WARNING:tensorflow:Calling predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# WARNING:tensorflow:Calling predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# [ 1.  0.  0.]
# 'accordion'

# %%
url = '../data/stop.jpg'
image = imread(url) # load an image
image.shape
# Out:
# (1200, 1800, 3)

# %%
imshow(image)

# %%
import random
random_x_coordinate = random.choice(range(1,image.shape[0]))
random_y_coordinate = random.choice(range(1,image.shape[0]))  # choose a random starting point
subset = image[random_y_coordinate:random_y_coordinate+128,random_x_coordinate:random_x_coordinate+128,]
imshow(subset)
print classifier.predict_proba(subset.reshape(49152))[0]
code_to_target[classifier.predict(subset.reshape(49152))[0]]
# Out:
# WARNING:tensorflow:Calling predict_proba (from tensorflow.contrib.learn.python.learn.estimators.dnn) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# WARNING:tensorflow:Calling predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# WARNING:tensorflow:Calling predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# WARNING:tensorflow:Calling predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# [ 0.  0.  0.  1.]
# 'stop_sign'

# %%
# Why might naive bayes be bad for this?
# how about KNN?
# Think about how they work that make them a bad candidate
